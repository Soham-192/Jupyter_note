# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Data Science Tools and Ecosystem

# %% [markdown]
# <h5>Introduction</h5>
# <p>Data science involves using tools like Python, R, and SQL for data analysis, visualization, and machine learning. Libraries such as Pandas, Scikit-learn, and TensorFlow support these tasks, while big data tools like Apache Spark handle large datasets. Jupyter Notebooks and Google Colab provide interactive environments for coding and documentation. These tools streamline workflows from data extraction to model development and sharing results.

# %% [markdown]
# <h5>Data Languages:</h5>
#
# 1. python
# 2. R
# 3. SQL
# 4. Scala

# %% [markdown]
# Here are 5 commonly used data science libraries:
#
# 1. Pandas: For data manipulation and analysis, especially using DataFrames.
# 2. NumPy: For numerical computations and handling multi-dimensional arrays.
# 3. Matplotlib: For creating static, animated, and interactive visualizations.
# 4. Scikit-learn: For implementing machine learning algorithms and statistical modeling.
# 5. TensorFlow: For building and training deep learning models.

# %% [markdown]
# | Data Science Tools              |
# |----------------------------------|
# | Jupyter Notebooks                |
# | Google Colab                     |
# | RStudio                          |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# 1. **Addition**: `5 + 3 = 8`
# 2. **Subtraction**: `10 - 4 = 6`
# 3. **Multiplication**: `7 * 3 = 21`
# 4. **Division**: `20 / 5 = 4.0`
# 5. **Exponentiation**: `2 ** 3 = 8`
# 6. **Modulus**: `10 % 3 = 1`

# %%
#multiplication
a=10
b=20
print("product: ",a*b)
#addition
a=10
b=20
print("Sum: ",a+b)
# Out:
# product:  200
# Sum:  30

# %%
#hours to minutes
hours=5
minutes=hours*60
print("Minute Corresponding to given hours is: ",minutes)
# Out:
# Minute Corresponding to given hours is:  300

# %% [markdown]
# **Objectives:**
#
# - **List popular languages for Data Science**: Identify and understand the programming languages commonly used in data science, such as Python, R, and SQL, and their roles in data manipulation, analysis, and visualization.
#
# - **Understand commonly used libraries in Data Science**: Familiarize yourself with essential libraries in Python and R that support data science tasks. This includes libraries like Pandas for data manipulation, NumPy for numerical computations, Matplotlib and Seaborn for data visualization, and Scikit-learn for machine learning.
#
# - **Explore various data science tools and environments**: Gain insight into the tools and environments that facilitate data science workflows, including Jupyter Notebooks, Google Colab, and RStudio, and understand how they can enhance productivity and collaboration.
#
# - **Practice arithmetic operations in Python**: Learn to perform basic arithmetic operations in Python, including addition, subtraction, multiplication, division, and modulus, to build a foundation for more complex calculations in data analysis.
#
# - **Learn to create tables and lists in Jupyter Notebook**: Acquire skills in formatting and presenting data in Jupyter Notebooks using Markdown, including creating ordered and unordered lists, and building tables to organize information effectively.

# %% [markdown]
# <h2>Author :</h2>
#
# Soham Ghosh
